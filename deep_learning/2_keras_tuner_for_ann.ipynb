# %%
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense
from kerastuner.tuners import RandomSearch

# %%
df = pd.read_csv("https://raw.githubusercontent.com/krishnaik06/Keras-Tuner/main/Real_Combine.csv")
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
def build_model(hp):
    model = Sequential()
    for i in range(hp.Int("num_layers",2,20)):
        model.add(Dense(units=hp.Int("units_"+str(i),
                                           min_value=32,
                                           max_value=512,
                                           step=32),
                        activation="relu"))
    model.add(Dense(1, activation="linear"))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice("learning_rate", [1e-2,1e-3,1e-4])),
        loss="mean_absolute_error",
        metrics=["mean_absolute_error"])
    return model

# %%
tuner = RandomSearch(build_model, objective="val_mean_absolute_error",
                    max_trials=5, executions_per_trial=3, directory="project1",
                    project_name="air_quality_index")

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
tuner.search(X_train, y_train, epochs=5,
             validation_data=(X_test, y_test))
# Out:
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |4                 |?
# units_0           |416               |?
# units_1           |448               |?
# learning_rate     |0.01              |?
#
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 15ms/step - loss: nan - mean_absolute_error: nan - val_loss: 62.8521 - val_mean_absolute_error: 62.8521
# Epoch 2/5
# 24/24 [==============================] - 0s 7ms/step - loss: nan - mean_absolute_error: nan - val_loss: 56.5434 - val_mean_absolute_error: 56.5434
# Epoch 3/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.6132 - val_mean_absolute_error: 65.6132
# Epoch 4/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 53.4298 - val_mean_absolute_error: 53.4298
# Epoch 5/5
# 24/24 [==============================] - 0s 7ms/step - loss: nan - mean_absolute_error: nan - val_loss: 47.1611 - val_mean_absolute_error: 47.1611
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 62.7624 - val_mean_absolute_error: 62.7624
# Epoch 2/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 59.8212 - val_mean_absolute_error: 59.8212
# Epoch 3/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 50.0469 - val_mean_absolute_error: 50.0469
# Epoch 4/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 50.2746 - val_mean_absolute_error: 50.2746
# Epoch 5/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 46.4740 - val_mean_absolute_error: 46.4740
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 9ms/step - loss: nan - mean_absolute_error: nan - val_loss: 60.5141 - val_mean_absolute_error: 60.5141
# Epoch 2/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 55.7913 - val_mean_absolute_error: 55.7913
# Epoch 3/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 58.2687 - val_mean_absolute_error: 58.2687
# Epoch 4/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 49.2024 - val_mean_absolute_error: 49.2024
# Epoch 5/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 46.9107 - val_mean_absolute_error: 46.9107
#
# Trial 1 Complete [00h 00m 04s]
# val_mean_absolute_error: 46.848592122395836
#
# Best val_mean_absolute_error So Far: 46.848592122395836
# Total elapsed time: 00h 00m 04s
#
# Search: Running Trial #2
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |5                 |4
# units_0           |64                |416
# units_1           |32                |448
# learning_rate     |0.01              |0.01
# units_2           |256               |32
# units_3           |96                |32
# C:\Users\ujwal\anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 12ms/step - loss: nan - mean_absolute_error: nan - val_loss: 61.9085 - val_mean_absolute_error: 61.9085
# Epoch 2/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 61.6239 - val_mean_absolute_error: 61.6239
# Epoch 3/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 56.4018 - val_mean_absolute_error: 56.4018
# Epoch 4/5
# 24/24 [==============================] - 0s 2ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.9663 - val_mean_absolute_error: 64.9663
# Epoch 5/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 51.7660 - val_mean_absolute_error: 51.7660
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 62.6701 - val_mean_absolute_error: 62.6701
# Epoch 2/5
# 24/24 [==============================] - 0s 2ms/step - loss: nan - mean_absolute_error: nan - val_loss: 73.1294 - val_mean_absolute_error: 73.1294
# Epoch 3/5
# 24/24 [==============================] - 0s 2ms/step - loss: nan - mean_absolute_error: nan - val_loss: 57.1364 - val_mean_absolute_error: 57.1364
# Epoch 4/5
# 24/24 [==============================] - 0s 2ms/step - loss: nan - mean_absolute_error: nan - val_loss: 52.5008 - val_mean_absolute_error: 52.5008
# Epoch 5/5
# 24/24 [==============================] - 0s 2ms/step - loss: nan - mean_absolute_error: nan - val_loss: 54.2689 - val_mean_absolute_error: 54.2689
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.7736 - val_mean_absolute_error: 63.7736
# Epoch 2/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 59.8408 - val_mean_absolute_error: 59.8408
# Epoch 3/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 55.5328 - val_mean_absolute_error: 55.5328
# Epoch 4/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 50.5678 - val_mean_absolute_error: 50.5678
# Epoch 5/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 53.4441 - val_mean_absolute_error: 53.4441
#
# Trial 2 Complete [00h 00m 03s]
# val_mean_absolute_error: 51.61154429117838
#
# Best val_mean_absolute_error So Far: 46.848592122395836
# Total elapsed time: 00h 00m 08s
#
# Search: Running Trial #3
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |3                 |4
# units_0           |192               |416
# units_1           |320               |448
# learning_rate     |0.0001            |0.01
# units_2           |32                |32
# units_3           |192               |32
# units_4           |384               |None
# C:\Users\ujwal\anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 9ms/step - loss: nan - mean_absolute_error: nan - val_loss: 83.5696 - val_mean_absolute_error: 83.5696
# Epoch 2/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.7025 - val_mean_absolute_error: 64.7025
# Epoch 3/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.4652 - val_mean_absolute_error: 64.4652
# Epoch 4/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.1155 - val_mean_absolute_error: 64.1155
# Epoch 5/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.5971 - val_mean_absolute_error: 63.5971
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 69.9850 - val_mean_absolute_error: 69.9850
# Epoch 2/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.6244 - val_mean_absolute_error: 63.6244
# Epoch 3/5
# 24/24 [==============================] - 0s 2ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.2330 - val_mean_absolute_error: 64.2330
# Epoch 4/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.0129 - val_mean_absolute_error: 63.0129
# Epoch 5/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.2629 - val_mean_absolute_error: 64.2629
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 7ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.9615 - val_mean_absolute_error: 65.9615
# Epoch 2/5
# 24/24 [==============================] - 0s 2ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.0499 - val_mean_absolute_error: 63.0499
# Epoch 3/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 62.5954 - val_mean_absolute_error: 62.5954
# Epoch 4/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 62.9840 - val_mean_absolute_error: 62.9840
# Epoch 5/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 62.1608 - val_mean_absolute_error: 62.1608
#
# Trial 3 Complete [00h 00m 03s]
# val_mean_absolute_error: 62.923583984375
#
# Best val_mean_absolute_error So Far: 46.848592122395836
# Total elapsed time: 00h 00m 11s
#
# Search: Running Trial #4
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |4                 |4
# units_0           |320               |416
# units_1           |448               |448
# learning_rate     |0.01              |0.01
# units_2           |384               |32
# units_3           |224               |32
# units_4           |288               |None
# C:\Users\ujwal\anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 13ms/step - loss: nan - mean_absolute_error: nan - val_loss: 60.8502 - val_mean_absolute_error: 60.8502
# Epoch 2/5
# 24/24 [==============================] - 0s 7ms/step - loss: nan - mean_absolute_error: nan - val_loss: 54.3284 - val_mean_absolute_error: 54.3284
# Epoch 3/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 58.5223 - val_mean_absolute_error: 58.5223
# Epoch 4/5
# 24/24 [==============================] - 0s 7ms/step - loss: nan - mean_absolute_error: nan - val_loss: 45.3316 - val_mean_absolute_error: 45.3316
# Epoch 5/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 48.1181 - val_mean_absolute_error: 48.1181
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 10ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.4379 - val_mean_absolute_error: 64.4379
# Epoch 2/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.2372 - val_mean_absolute_error: 63.2372
# Epoch 3/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 69.3839 - val_mean_absolute_error: 69.3839
# Epoch 4/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 49.9421 - val_mean_absolute_error: 49.9421
# Epoch 5/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 49.2390 - val_mean_absolute_error: 49.2390
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 9ms/step - loss: nan - mean_absolute_error: nan - val_loss: 66.0488 - val_mean_absolute_error: 66.0488
# Epoch 2/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 61.8551 - val_mean_absolute_error: 61.8551
# Epoch 3/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 53.1683 - val_mean_absolute_error: 53.1683
# Epoch 4/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 61.0605 - val_mean_absolute_error: 61.0605
# Epoch 5/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 48.7446 - val_mean_absolute_error: 48.7446
#
# Trial 4 Complete [00h 00m 04s]
# val_mean_absolute_error: 47.771728515625
#
# Best val_mean_absolute_error So Far: 46.848592122395836
# Total elapsed time: 00h 00m 16s
#
# Search: Running Trial #5
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |4                 |4
# units_0           |160               |416
# units_1           |384               |448
# learning_rate     |0.0001            |0.01
# units_2           |96                |32
# units_3           |416               |32
# units_4           |128               |None
# C:\Users\ujwal\anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 10ms/step - loss: nan - mean_absolute_error: nan - val_loss: 66.1482 - val_mean_absolute_error: 66.1482
# Epoch 2/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.0630 - val_mean_absolute_error: 64.0630
# Epoch 3/5
# 24/24 [==============================] - 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.6590 - val_mean_absolute_error: 64.6590
# Epoch 4/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.5214 - val_mean_absolute_error: 64.5214
# Epoch 5/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.3660 - val_mean_absolute_error: 63.3660
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 66.6528 - val_mean_absolute_error: 66.6528
# Epoch 2/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.5081 - val_mean_absolute_error: 63.5081
# Epoch 3/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.6222 - val_mean_absolute_error: 63.6222
# Epoch 4/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.4637 - val_mean_absolute_error: 63.4637
# Epoch 5/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.0255 - val_mean_absolute_error: 64.0255
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 66.1529 - val_mean_absolute_error: 66.1529
# Epoch 2/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.8714 - val_mean_absolute_error: 63.8714
# Epoch 3/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.4694 - val_mean_absolute_error: 64.4694
# Epoch 4/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.0096 - val_mean_absolute_error: 64.0096
# Epoch 5/5
# 24/24 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.8175 - val_mean_absolute_error: 63.8175
#
# Trial 5 Complete [00h 00m 03s]
# val_mean_absolute_error: 63.54905446370443
#
# Best val_mean_absolute_error So Far: 46.848592122395836
# Total elapsed time: 00h 00m 19s
# INFO:tensorflow:Oracle triggered exit
# C:\Users\ujwal\anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project1\air_quality_index
# Showing 10 best trials
# Objective(name='val_mean_absolute_error', direction='min')
# Trial summary
# Hyperparameters:
# num_layers: 4
# units_0: 416
# units_1: 448
# learning_rate: 0.01
# units_2: 32
# units_3: 32
# Score: 46.848592122395836
# Trial summary
# Hyperparameters:
# num_layers: 4
# units_0: 320
# units_1: 448
# learning_rate: 0.01
# units_2: 384
# units_3: 224
# units_4: 288
# Score: 47.771728515625
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 64
# units_1: 32
# learning_rate: 0.01
# units_2: 256
# units_3: 96
# units_4: 32
# Score: 51.61154429117838
# Trial summary
# Hyperparameters:
# num_layers: 3
# units_0: 192
# units_1: 320
# learning_rate: 0.0001
# units_2: 32
# units_3: 192
# units_4: 384
# Score: 62.923583984375
# Trial summary
# Hyperparameters:
# num_layers: 4
# units_0: 160
# units_1: 384
# learning_rate: 0.0001
# units_2: 96
# units_3: 416
# units_4: 128
# Score: 63.54905446370443
